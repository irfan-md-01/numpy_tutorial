# %%
import requests
from bs4 import BeautifulSoup

# %%
word = "Redmi note 11"
word=word.replace(" ","+")
print(word)
# Out:
# Redmi+note+11

# %%
ebay = f"https://www.ebay.com/sch/i.html?_nkw={word}&"
flipcart =f"https://www.flipkart.com/search?q={word}&sort=popularity"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0'}

# %%
a = {}
f = {}
ebay
# Out:
# 'https://www.ebay.com/sch/i.html?_nkw=Redmi+note+11&'

# %%
r = requests.get(ebay,headers=headers)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,"html.parser")
product_containers = soup.find_all('div', class_='s-item__info')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 soup = BeautifulSoup(r.text,"html.parser")
#       2 product_containers = soup.find_all('div', class_='s-item__info')
#
# NameError: name 'r' is not defined

# %%
product = {}
i = 0
for container in product_containers:
            if(i==0) : 
                i+=1
                continue
            name = container.find('div', class_='s-item__title').text.strip()
            price = container.find('span', class_='s-item__price').text.strip()
            link = container.find('a', class_='s-item__link')['href']
            print(name)
            print("a"+str((float(price[1:]))*83.43))
            print(link)
            i+=1
            if(i==5): break
# Out:
# Redmi Note 11 5G Factory Unlocked Cell Phone 256GB GSM INT'L Version (CN) BK
# a11886.2721
# https://www.ebay.com/itm/226102410147?itmmeta=01HWN936NMY6BG05A0EHDS2MET&hash=item34a4c0fba3:g:LDEAAOSwpgBl1Vhg&itmprp=enc%3AAQAJAAAA4MKXZw%2Fh5NLb6C5oQuPXRDUPNsZ10Ah4w4yQ0PB9IkZSUfg7LxQmiIjSP0HlKzxW4G8riskksDqB61mCP9lonnzBO6WUm1%2FuO2dJ6of2bj1St7KMSpKDVP%2FkOYxcFL2VPud5BZ7Wu%2FNBRDU29rofgkyJrxSFyc7efjuNUT6kq9d7QRWbnnC1D1OTtBg680kDb7QA7GlvpjkBOanQzew7oLFETdIbUuNKYG90--lzSt2bsCUA1Zjuk3E26lUr27iKHbno8mF9oNQBbSclNcDv6%2FMHNbM1cr4V92BiaE3zcNT9%7Ctkp%3ABFBM-uqMqeVj
# Redmi Note 11E Pro 5G Factory Unlocked Cell Phone 6.6" inches 128GB/8GB CH V. GR
# a15256.844100000002
# ...

# %%
# urls = []
# product_urls = soup.find_all('a', class_='_1fQZEK')
# i=0;
# for links in product_urls :
#     urls.append((links.get("href")))
#     if(i==2): break
#     i+=1
    
# urls
# Out:
# ['/redmi-note-11-horizon-blue-128-gb/p/itm5cc0b8e0001d9?pid=MOBGHDXJVF6QJMJD&lid=LSTMOBGHDXJVF6QJMJD1FDIHQ&marketplace=FLIPKART&q=Redmi+note+11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=090fa2b9-1268-472f-9cc3-9c666cdd2438.MOBGHDXJVF6QJMJD.SEARCH&ppt=None&ppn=None&ssid=9vfuda9m3k0000001713376177895&qH=95970eda4747e9d7',
#  '/redmi-note-11s-horizon-blue-64-gb/p/itmd5a2c088fa559?pid=MOBGK2GF59Z7GNMP&lid=LSTMOBGK2GF59Z7GNMPXKKRKE&marketplace=FLIPKART&q=Redmi+note+11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=090fa2b9-1268-472f-9cc3-9c666cdd2438.MOBGK2GF59Z7GNMP.SEARCH&ppt=None&ppn=None&ssid=9vfuda9m3k0000001713376177895&qH=95970eda4747e9d7',
# ...

# %%
product_titles = soup.find_all('div', class_='_4rR01T')
product_prices = soup.find_all('div', class_='_30jeq3 _1_WHN1')
i=0
for title, price in zip(product_titles, product_prices):
    if(i>2): break
    f[f"title{i}"]= title.text.strip()
    f[f"price{i}"]= price.text.strip()
    f[f"url{i}"]= "https://www.flipkart.com"+urls[i]
    i+=1

# %%
print(f)
# Out:
# {'title0': 'REDMI Note 11 (Horizon Blue, 128 GB)', 'price0': '₹11,590', 'url0': 'https://www.flipkart.com/redmi-note-11-horizon-blue-128-gb/p/itm5cc0b8e0001d9?pid=MOBGHDXJVF6QJMJD&lid=LSTMOBGHDXJVF6QJMJD1FDIHQ&marketplace=FLIPKART&q=Redmi+note+11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=090fa2b9-1268-472f-9cc3-9c666cdd2438.MOBGHDXJVF6QJMJD.SEARCH&ppt=None&ppn=None&ssid=9vfuda9m3k0000001713376177895&qH=95970eda4747e9d7', 'title1': 'REDMI Note 11S (Horizon Blue, 64 GB)', 'price1': '₹12,700', 'url1': 'https://www.flipkart.com/redmi-note-11s-horizon-blue-64-gb/p/itmd5a2c088fa559?pid=MOBGK2GF59Z7GNMP&lid=LSTMOBGK2GF59Z7GNMPXKKRKE&marketplace=FLIPKART&q=Redmi+note+11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=090fa2b9-1268-472f-9cc3-9c666cdd2438.MOBGK2GF59Z7GNMP.SEARCH&ppt=None&ppn=None&ssid=9vfuda9m3k0000001713376177895&qH=95970eda4747e9d7', 'title2': 'REDMI Note 11S (Horizon Blue, 128 GB)', 'price2': '₹13,490', 'url2': 'https://www.flipkart.com/redmi-note-
# ...

# %%
URL =f"https://www.amazon.com/s?k={word}"
URL
# Out:
# 'https://www.amazon.com/s?k=Redmi+note+11'

# %%
HEADERS = ({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [503]>
