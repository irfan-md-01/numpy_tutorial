# %% [markdown]
# Problem Statement: **Data Visualization III**
#
# * **Load the dataset**: Download and load the Iris dataset into a Pandas DataFrame.
# * **Inspect dataset**: View column names, data types, and basic statistics.
# * **List features and types**: Identify feature names and classify as numeric or nominal.
# * **Plot histograms**: Use Seaborn/Matplotlib to plot histograms for all numeric features.
# * **Plot box plots**: Create box plots for each numeric feature to view spread and potential outliers.
# * **Compare distributions**: Analyze feature distributions and identify any visible outliers or skewness.

# %% [markdown]
# ### Import Required Libraries

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Dataset

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Inspect Dataset Structure

# %%
print("Column Names and Data Types:\n", df.dtypes)
print("\nStatistical Summary:\n", df.describe())
# Out:
# Column Names and Data Types:
#  sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# Statistical Summary:
#         sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### List Features and Classify as Numeric or Nominal

# %%
# List all columns
features = df.columns.tolist()
print("All Features:", features)
# Out:
# All Features: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
# Separate numeric and nominal features
numeric_features = df.select_dtypes(include='number').columns.tolist()
nominal_features = df.select_dtypes(exclude='number').columns.tolist()

# %%
print("\nNumeric Features:", numeric_features)
print("Nominal Features:", nominal_features)
# Out:
# Numeric Features: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
# Nominal Features: ['species']

# %% [markdown]
# ### Plot Histograms for All Numeric Features

# %%
df[numeric_features].hist(bins=15);

# %%
df[numeric_features].hist(bins=15, figsize=(10, 6), layout=(2, 2), edgecolor='black')
plt.suptitle('Histograms of Numeric Features', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot Box Plots for Each Numeric Feature

# %%
sns.boxplot(y=df[numeric_features[0]])
plt.show()
sns.boxplot(y=df[numeric_features[1]])
plt.show()
sns.boxplot(y=df[numeric_features[2]])
plt.show()
sns.boxplot(y=df[numeric_features[3]])
plt.show()

# %%
# Set plot size
plt.figure(figsize=(12, 6))

# Create boxplots
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(1, 4, i)
    sns.boxplot(y=df[feature])
    plt.title(feature)

plt.suptitle('Box Plots of Numeric Features', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations:
#
# 1. **Histograms**:
#    - Most numeric features show a roughly normal distribution.
#    - 'petal_length' and 'petal_width' show skewed distributions with clear species-based separation.
#
# 2. **Box Plots**:
#    - 'sepal_width' contains visible outliers.
#    - 'petal_length' and 'petal_width' have greater spread and more pronounced variation.
#    - 'sepal_length' shows a fairly symmetrical distribution.
#
# 3. **Skewness and Outliers**:
#    - 'sepal_width' is slightly left-skewed and contains outliers.
#    - 'petal_width' has low values with a long tail to the right.
